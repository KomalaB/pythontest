# %%
###Assignment7
##
####
####1.Get two numbers from the user and display the total of all the numbers between them.
####from Vijaya to everyone:    5:32 PM
####2. Accept 2 numbers and display the smallest of the two
####from Vijaya to everyone:    5:33 PM
####3.write a function printSquare(num) , which will print the square of a given number
##
##num1=int(input("enter the first number : "))
##num2=int(input("enter the 2nd number : "))
##
##count=0
##num=num1
##num1=num1+1
##def Num_check(num1,num2):
##   # num=num1
##    #num1=num1+1
##   # if(num1<num2):
##
##    while (Count>0):
##        if(num1<num2):
##            num=num1
##            print(num1)
##            num1=nu8m1+1
##        else:8
##            print(num2," is smaller than", num)
##     count=count+1
##   break
##     # num2=int(input("Re-enter the 2nd number : "))
##    #return num1 + num2
##num2=int(input("9Re-enter the 2nd number : "))
##Num_check(num1,num2)
###num2=int(input("Re-enter the 2nd number : "))
###print(num2)
##
###Num_check(num1,num2)
##



def Num_check(num1,num2):
      #  num1=num1+1
    def Num_check2():
        while (num1<num2):
            print(num1)
            num1=num1+1
            if(num1==num2):
                break
                print("End of Sequesnce")
        return

 #  if(num2<num1):
    print(+num2," is smaller than", +num)
    num2=int(input("Re-enter the 2nd number : "))
  #  Num_check(num1,num2)

    #return num1 + num2
    #Num_check(num1,num2)
    #return num1 + num2

num1=int(input("enter the first number : "))
num2=int(input("enter the 2nd number : "))

num=num1
num1=num1+1

Num_check(num1,num2)
